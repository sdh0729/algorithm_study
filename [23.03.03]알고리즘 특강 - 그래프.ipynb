# %%
# 함수
class Graph():
  def __init__(self,size):
    self.graph = [ [0 for _ in range(size)]for _ in range(size)]
# 전역
G1 = None
A,B,C,D = 1,2,3,4

# 메인
G1 = Graph(4)

G1.graph[A][B] = 1;G1.graph[A][C] = 1;G1.graph[A][D] = 1
G1.graph[B][A] = 1;G1.graph[B][C] = 1
G1.graph[C][A] = 1;G1.graph[C][B] = 1;G1.graph[C][D] = 1
G1.graph[D][A] = 1;G1.graph[D][C] = 1
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-4-38e0d44b4e10> in <module>
#      10 G1 = Graph(4)
#      11
# ---> 12 G1.graph[A][B] = 1;G1.graph[A][C] = 1;G1.graph[A][D] = 1
#      13 G1.graph[B][A] = 1;G1.graph[B][C] = 1
#      14 G1.graph[C][A] = 1;G1.graph[C][B] = 1;G1.graph[C][D] = 1
#
# IndexError: list assignment index out of range
